# %% [markdown]
# # Enable GPU
# * Go to "Runtime" -> "Change Runtime Type"
# * Choose "T4 GPU" under "Hardware Accelerator"
# * Click "Save"

# %% [markdown]
# # Install Libraries

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.34.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /home/legend/anaconda3/lib/python3.12/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/legend/anaconda3/lib/python3.12/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /home/legend/anaconda3/lib/python3.12/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /home/legend/anaconda3/lib/python3.12/site-packages (from accelerate) (6.0.1)
# Collecting torch>=1.10.0 (from accelerate)
#   Downloading torch-2.4.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading huggingface_hub-0.25.1-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /home/legend/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/legend/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.3.1)
# Requirement already satisfied: requests in /home/legend/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in /home/legend/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/legend/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /home/legend/anaconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/legend/anaconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /home/legend/anaconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: setuptools in /home/legend/anaconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (69.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=1.10.0->accelerate)
#   Downloading triton-3.0.0-1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/legend/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/legend/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/legend/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/legend/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/legend/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath>=0.19 in /home/legend/anaconda3/lib/python3.12/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-0.34.2-py3-none-any.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 8.4 MB/s eta 0:00:000:00:01
# Downloading huggingface_hub-0.25.1-py3-none-any.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.4/436.4 kB 9.8 MB/s eta 0:00:0011.5 MB/s eta 0:00:01
# Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.8/434.8 kB 10.4 MB/s eta 0:00:0031m11.6 MB/s eta 0:00:01
# Downloading torch-2.4.1-cp312-cp312-manylinux1_x86_64.whl (797.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 MB 1.1 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 27.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 25.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 600.2/664.8 MB 56.8 MB/s eta 0:00:02^C2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 601.6/664.8 MB 56.5 MB/s eta 0:00:02
# ERROR: Operation cancelled by user

# %% [markdown]
# The accelerate library optimizes how our code interacts with the GPU, making the most of Colab's hardware.
#
# # LLM setup and configuration

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# Specify the LLM model we'll be using
model_name = "microsoft/Phi-3-mini-4k-instruct"

# Configure for GPU usage
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16,
    trust_remote_code=True,
)

# Load the tokenizer for the chosen model
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Create a pipeline object for easy text generation with the LLM
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]

# %% [markdown]
# Importing Libraries: We bring in required modules from the hugging face (hf) transformers library to work with the language model.
# Specifing LLM to use: We specify the hf repository [microsoft/Phi-3-mini-4k-instruct](<https://huggingface.co/microsoft/Phi-3-mini-4k-instruct>) to load the instruct LLM from.
# Loading the Model and Tokenizer: We load the LLM and its associated tokenizer, which prepares them for use.
# Creating a Pipeline: We set up a hf pipeline object to streamline sending prompts and getting responses from the LLM.
#
# # Configure LLM generation parameters

# %%
# Parameters to control LLM's response generation
generation_args = {
    "max_new_tokens": 512,     # Maximum length of the response
    "return_full_text": False,      # Only return the generated text
}

# %% [markdown]
# This code defines settings to manage the LLM's text generation behavior.
#
# max_new_tokens: limits the response length.
# return_full_text: ensures we only get the newly generated part of the response.
#
# # Builing the query function

# %%
def chat(input):

  messages = [
      {"role": "user", "content": input}
  ]

  output = pipe(messages, **generation_args)
  return output[0]['generated_text']

# %%
input1 = 'how are you today?'

response = chat(input3)
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-217293825734> in <cell line: 3>()
#       1 input1 = 'how are you today?'
#       2
# ----> 3 response = chat(input3)
#       4 print(response)
#
# NameError: name 'chat' is not defined

# %% [markdown]
# pip uninstall torch huggingface_hub nvidia_cublas nvidia_cuda_runtime -y

# %%
pip cache purge
# Out:
# Files removed: 86
# Note: you may need to restart the kernel to use updated packages.

# %%
conda clean --all
# Out:
# Will remove 522 (984.7 MB) tarball(s).
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
y

# %%
sudo rm -rf /tmp/*
